# %% [markdown]
# ## EPA Product System Hackathon
# OK, it's May 15- we have until May 30 to get something sweee-e-et finished.  What's it going to be?
#
# Here's the plan:
#  * make a forest of fragments from the spreadsheet product models
#  * generate list of interior nodes and cutoffs (via automatic traversal)
#  * manually process "laundry list" terminations
#    - get USEEIO working
#    - use USLCI
#    - use Ecoinvent
#    - use ELCD
#  * automatically terminate cutoff fragments to various processes, by scenario
#
# First task is to read the spreadsheets, and build the fragments

# %% [markdown]
# ## First Task: validate spreadsheets
# The only potentially invalid information in the spreadsheets is the parent-child relationship between parts and assemblies; MSrocka announced that the initial commit failed this validation. So here is a check.

# %%
import os
import xlrd

# %%
fg_dir = '/data/GitHub/2019/LCAproductsystemassembly_1/data-foreground/'
bg_dir = '/data/GitHub/2019/LCAproductsystemassembly_resources/data-background/'


class DuplicateAssembly(Exception):
    pass

# %%
from antelope_catalog.providers.xl_dict  import XlDict

# %%
def validate_sheet(sheet):
    """
    checks whether the sheet includes references to unrecognized assemblies; returns the names of the 
    unrecognized assemblies
    """
    xld = XlDict(sheet)
    seen = set()
    dups = set()
    for i, row in xld.iterrows():
        parent = row['Next Assembly']
        part = row['Part Number']
        if parent is not None:
            if parent not in seen:
                yield parent
            if parent in dups:
                raise DuplicateAssembly('%s (row %d)' % (parent, i))
                
        if part in seen:
            dups.add(part)
            print('!Duplicate part: %s (row %d)' % (part, i))
            
        else:
            seen.add(part)

# %%
def validate_workbook(book):
    all_m = set()
    for n in book.sheet_names():
        s = book.sheet_by_name(n)
        m = set(k for k in validate_sheet(s))
        print('%s: %s' % (n, m))
        all_m |= m
    return all_m

# %%
def validate_folder(folder):
    asm = set()
    mis = set()
    xlss = [k for k in os.listdir(folder)]
    for xls in xlss:
        try:
            xl = xlrd.open_workbook(os.path.join(folder, xls))
        except xlrd.XLRDError:
            continue
        print('Workbook: %s' % xls)
        print('Assemblies: %s' % xl.sheet_names())
        asm |= set(xl.sheet_names())
        
        m = validate_workbook(xl)
        print('Missing: %s\n' % m)
        mis |= m
    print('Cross-References: %s' % (asm & mis))
    print('Globally Missing: %s' % (mis - asm))

# %% [raw]
# # initial commit
# >>> validate_folder(fg_dir)
# Workbook: NLG F18EFG ABL.xlsx
# Assemblies: ['74A430500-1017', '74A430700-1009', '74A430800-1021']
# 74A430500-1017: set()
# 74A430700-1009: set()
# 74A430800-1021: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# 74A400500-1017: {'74A400600-1017', '74A400631-2003'}
# 74A400500-1018: {'74A400600-1017', '74A400631-2003'}
# 74A400700-1013: {'74A400700-2009', '74A400780-1001', '74A400700-1011'}
# 74A400700-1014: {'74A400700-1012', '74A400780-1001', '74A400700-2009'}
# 74A400800-1001: set()
# Missing: {'74A400780-1001', '74A400631-2003', '74A400700-1011', '74A400700-1012', '74A400600-1017', '74A400700-2009'}
#
# Cross-References: set()
# Globally Missing: {'74A400780-1001', '74A400700-1011', '74A400631-2003', '74A400700-2009', '74A400700-1012', '74A400600-1017'}

# %%
# updated-- we see the _c file has no validation errors
validate_folder(fg_dir)
# Out:
# Workbook: NLG F18EFG ABL.xlsx
# Assemblies: ['74A430500-1017', '74A430700-1009', '74A430800-1021']
# !Duplicate part: NAS516-1A (row 46)
# !Duplicate part: NAS516-1A (row 54)
# !Duplicate part: M83461/1-010 (row 67)
# !Duplicate part: AS5986-04 (row 69)
# !Duplicate part: NAS516-1A (row 70)
# !Duplicate part: MS20427M2C5 (row 134)
# !Duplicate part: M23053/6-105-0 (row 173)
# !Duplicate part: M23053/6-105-0 (row 176)
# !Duplicate part: NAS516-1A (row 248)
# !Duplicate part: MS24665-153 (row 251)
# !Duplicate part: MS24665-302 (row 252)
# !Duplicate part: NAS516-1A (row 268)
# !Duplicate part: 74A450914-2003 (row 281)
# !Duplicate part: 74A450982-2003 (row 282)
# !Duplicate part: 74A430912-2001 (row 294)
# !Duplicate part: 74A430979-2003 (row 309)
# !Duplicate part: 74A430979-2003 (row 312)
# !Duplicate part: 74A430954-2001 (row 319)
# !Duplicate part: M83461/1-010 (row 329)
# !Duplicate part: AS5986-04 (row 333)
# !Duplicate part: MS24665-153 (row 356)
# !Duplicate part: MS24665-302 (row 357)
# !Duplicate part: ST3M404C4 (row 362)
# !Duplicate part: ST3M404C6 (row 363)
# !Duplicate part: NAS1149E0432P (row 366)
# !Duplicate part: NAS1149E0463P (row 367)
# !Duplicate part: NAS1149E0632P (row 368)
# !Duplicate part: MS20995C32 (row 372)
# !Duplicate part: NAS516-1A (row 391)
# !Duplicate part: MS24665-151 (row 404)
# !Duplicate part: MS24665-302 (row 405)
# !Duplicate part: ST3M404C6 (row 409)
# !Duplicate part: NAS1149E0332P (row 410)
# !Duplicate part: NAS1149E0363P (row 411)
# !Duplicate part: NAS1149E0632P (row 412)
# !Duplicate part: NAS1149E0663P (row 413)
# !Duplicate part: MS20995C32 (row 424)
# 74A430500-1017: set()
# !Duplicate part: 74B430704-101 (row 18)
# !Duplicate part: 74B430705-103 (row 20)
# !Duplicate part: 74B430717-101 (row 27)
# 74A430700-1009: set()
# 74A430800-1021: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL_c.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1017: set()
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1018: set()
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1013: set()
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1014: set()
# 74A400800-1001: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1017: {'74A400600-1017', '74A400631-2003'}
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1018: {'74A400600-1017', '74A400631-2003'}
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1013: {'74A400700-1011', '74A400700-2009', '74A400780-1001'}
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1014: {'74A400700-2009', '74A400700-1012', '74A400780-1001'}
# 74A400800-1001: set()
# Missing: {'74A400700-2009', '74A400780-1001', '74A400600-1017', '74A400631-2003', '74A400700-1011', '74A400700-1012'}
#
# Cross-References: set()
# Globally Missing: {'74A400780-1001', '74A400600-1017', '74A400631-2003', '74A400700-2009', '74A400700-1011', '74A400700-1012'}

# %% [markdown]
# ## OK, on to the fragment building
# The Foreground interface allows us to create fragments, and the Qdb allows us to use canonical quantities by name.
#
# We observe that the spreadsheets include numerous duplicate parts, but no duplicate assemblies.  This means we don't need to worry about creating re-usable sub-fragments or checking them for consistency.

# %%
from antelope_catalog import LcCatalog

# %%
PROJECT_DIR = '/data/GitHub/2019/EPA_PSM_antelope/'
CAT = os.path.join(PROJECT_DIR, 'catalog')

# %%
cat = LcCatalog(CAT)
# Out:
# Loading JSON data from /data/GitHub/2019/EPA_PSM_antelope/catalog/reference-quantities.json:
# local.qdb: /data/GitHub/2019/EPA_PSM_antelope/catalog/reference-quantities.json
# local.qdb: /data/GitHub/lca-tools/lcatools/qdb/data/elcd_reference_quantities.json
# Adding masquerade [local.qdb] Number of items [Item(s)]
# Adding real entity elcd.3.2/flowproperties/01846770-4cfe-4a25-8ad9-919d8d378345
# Adding masquerade [local.qdb] Vehicle transport [Items*km]
# Adding real entity elcd.3.2/flowproperties/1cc347a0-3bd1-46db-a308-2707c68d2351
# Adding masquerade [local.qdb] Energy renewable and non renewable (gross calorific value) [MJ] [LCIA]
# Adding real entity elcd.3.2/flowproperties/23911c86-d4d2-4e3e-a45e-8e392af1dc4e
# Adding masquerade [local.qdb] Person transport [Items*km]
# Adding real entity elcd.3.2/flowproperties/4872c95a-5f78-4572-883b-e076187ad87c
# Adding masquerade [local.qdb] Recycled content (mass) [kg]
# Adding real entity elcd.3.2/flowproperties/52dcf2ff-c0f6-417f-a957-788688d67b86
# Adding masquerade [local.qdb] Carbon content (biogenic) [kg]
# Adding real entity elcd.3.2/flowproperties/62e503ce-544a-4599-b2ad-bcea15a7bf20
# Adding masquerade [local.qdb] Carbon content (fossil) [kg]
# Adding real entity elcd.3.2/flowproperties/64b8e725-b0ba-4837-abb9-62dc0e7b9f6f
# Adding masquerade [local.qdb] Electric energy [kWh]
# Adding real entity local.ecoinvent.3.2.cutoff/77ae64fa-7e74-4252-9c3b-889c1cd20bfc
# Adding masquerade [local.qdb] Exergy [MJ]
# Adding real entity elcd.3.2/flowproperties/79920f3d-77b3-4f12-8a8f-47accf832eca
# Adding masquerade [local.qdb] Water content (mass) [kg]
# Adding real entity elcd.3.2/flowproperties/7ec8d70e-4ffc-4024-86b7-6141cc0a2bf5
# Adding masquerade [local.qdb] Goods transport (mass*distance) [t*km]
# Adding real entity elcd.3.2/flowproperties/838aaa20-0117-11db-92e3-0800200c9a66
# Adding masquerade [local.qdb] Length [m]
# Adding real entity elcd.3.2/flowproperties/838aaa23-0117-11db-92e3-0800200c9a66
# Adding masquerade [local.qdb] Energy from renewable raw materials (net cal. value) [MJ] [LCIA]
# Adding real entity elcd.3.2/flowproperties/8695e049-7a18-4b83-b3bd-035747039652
# Adding masquerade [local.qdb] Mass [kg]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-11da-a746-0800200b9a66
# Adding masquerade [local.qdb] Net calorific value [MJ]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-11da-a746-0800200c9a66
# Adding masquerade [local.qdb] Normal Volume [m3]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-13da-a746-0800200c9a66
# Adding masquerade [local.qdb] Gross calorific value [MJ]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-14da-a746-0800200c9a66
# Adding masquerade [local.qdb] Area [m2]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-19da-a746-0800200c9a66
# Adding masquerade [local.qdb] Area*time [m2*a]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-21da-a746-0800200c9a66
# Adding masquerade [local.qdb] Volume [m3]
# Adding real entity elcd.3.2/flowproperties/93a60a56-a3c8-22da-a746-0800200c9a66
# Adding masquerade [local.qdb] Energy renewable and non renewable (net calorific value) [MJ] [LCIA]
# Adding real entity elcd.3.2/flowproperties/a182c00f-c0e5-4b7a-b2a1-a735fbee7f9a
# Adding masquerade [local.qdb] Price [EUR]
# Adding real entity elcd.3.2/flowproperties/bcf81c0a-9fe9-4b88-a25b-99e0dd64ddaa
# Adding masquerade [local.qdb] Duration [a]
# Adding real entity elcd.3.2/flowproperties/c0447923-0e60-4b3c-97c2-a86dddd9eea5
# Adding masquerade [local.qdb] Hydrogen content (mass) [kg]
# Adding real entity elcd.3.2/flowproperties/f3e1017d-1aa3-4763-b563-9494858e1ec7
# Adding masquerade [local.qdb] Market value US 2000, bulk prices [EUR]
# Adding real entity elcd.3.2/flowproperties/fdfecf14-ff8a-4e17-b2b2-f938c4b5cc27
# 25 new quantity entities added (25 total)
# 6 new flow entities added (6 total)

# %%
cat.show_interfaces()
# Out:
# local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon [basic, foreground, index]
# local.qdb [basic, index, quantity]

# %%
cat.get_resource('local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon').remove_archive()
fg = cat.create_foreground('psm-hackathon')
# Out:
# local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon: /data/GitHub/2019/EPA_PSM_antelope/catalog/psm-hackathon
# Loading /data/GitHub/2019/EPA_PSM_antelope/catalog/psm-hackathon
# 0 new fragment entities added (0 total)

# %%
xls = xlrd.open_workbook(os.path.join(fg_dir, 'MLG F18EFG ABL_c.xlsx'))
xl = xls.sheet_by_name(xls.sheet_names()[0])
# xld = XlDict(xl)

# %%
k = (42, 'seven')

# %%
i, j = k

# %%
j
# Out:
# 'seven'

# %%
'''
Define fragment:
 o- a "configurable exchange" 
 o- core elements are a flow and a direction
 o- optional elements: 
    - parent node (default None => reference flow)
    - termination node (default None => cutoff flow)
    - exchange value (ratio between parent node activity level and terminal flow magnitude; default 1.0)
 o- configurable elements: 
    - termination node
    - exchange value 

What's happening below is simple and general:
 - each row designates a unique fragment and represents a (non-unique) flow
 - determine and retrieve flow based on part number
   = if flow does not exist, create
 - determine and retrieve parent based on next assembly
   = if parent does not exist or is None, fragment becomes reference fragment and gets a name
   = if name is already taken, that tells us there's duplication happening

Foreground interface needs to provide:
 - way to create flows and fragments
 - way to retrieve flows and fragments by reference
 - generate existing fragments with flow (opt. direction)

What about duplication?  Here are some thoughts:
 - multiple fragments that generate the same flow are fine and encouraged- that is how fragments become useful
 - "named" fragments should be synonymous with (or maybe a subset of?) "reference fragments" i.e. fragments with 
   no parent node
   * dev question: is it operable to 'name' fragments on creation, e.g. bypassing foreground.name_fragment()?
     (should [RFC 2119 "SHALL"] work; needs unit test)
 - In the present case, duplication of fragment subtrees is not a technical problem if it happens within a fragment
   subtree, but it does indicate a design problem and should probably be detected.  It seems like an error if 
   two different subfragments produce the same assembly- if the two fragments are different, the assemblies should be
   different, and if they are the same- they should be represented by the same reference fragment. 
   
   If a new record (a) already has a matching fragment and (b) that fragment has child fragments, then it 
   is a duplicate assembly. Two different approaches to that:
    = assume the existing fragment is correct and use it, [somehow] ignoring child records
    = check to see whether the existing fragment is the same as the duplicative records and raise an exception if 
      it isn't
   
   The current spreadsheets seem to not have duplication of subassemblies, but we will plan to catch them and 
   raise an exception.
 
'''

def _row_to_flow(foreground, row):
    """
    This function is specific to the EPA foregrounds and should be the final disposition of the row dict. 
    Part Number is popped to retrieve flow.  Part Name is popped to set flow name.
    """
    if 'Next Assembly' in row:
        raise AttributeError('"Next Assembly" should be popped')
    flow_ref = row.pop('Part Number')
    if flow_ref is None:
        raise ValueError('Part number cannot be none (row %d)' % i)
    flow_name = row.pop('Part Name')
    if flow_name is None:
        flow_name = '%s ASSEMBLY' % flow_ref
    flow = foreground[flow_ref]
    if flow is None:
        flow = foreground.new_flow(flow_name, 'Number of items', external_ref=flow_ref, **row)
        if foreground[flow_ref] is not flow:
            raise KeyError('Flow ref %s failed to properly register' % flow_ref)
    return flow


def _new_reference_fragment(foreground, flow, **kwargs):
    # create a new parent fragment
    parent_ref = '%s ASSEMBLY' % flow.external_ref
    if foreground[parent_ref] is not None:
        _ac = 0
        while True:
            parent_ref = '%s ASSEMBLY alt %d' % (flow.external_ref, _ac)
            if foreground[parent_ref] is not None:
                _ac += 1
                continue
            break
    frag = foreground.new_fragment(flow, 'Output', Name=parent_ref, **kwargs)
    foreground.name_fragment(frag, parent_ref)
    return frag


def _process_row(foreground, i_row, source):
    i, row = i_row
    parent_num = row.pop('Next Assembly')
    flow = _row_to_flow(foreground, row)
    # print('%s: %s' % (source, flow))
        
    exis = [k for k in foreground.fragments_with_flow(flow) if len([c for c in k.child_flows]) > 0]
    if len(exis) > 0:
        raise DuplicateAssembly('(row %d) flow: %s' % (i, flow.link))  # handle this if it comes up
        
    if parent_num is None:
        t_frag = _new_reference_fragment(foreground, flow, Source=source)
        return t_frag
        #refs.append(t_frag)
        #    continue
    else:
        try:
            parent = next(foreground.fragments_with_flow(parent_num))
        except StopIteration:
            print('Bad parent reference: %s; creating new reference fragment' % parent_num)
            t_frag = _new_reference_fragment(foreground, flow, Source=source)
            return t_frag
                    
    frag = foreground.new_fragment(flow, 'Input', parent=parent, Source=source)
    return


def fragment_from_xl_sheet(foreground, sheet):
    """
    This function makes the following assumptions:
     - every record corresponds to a distinct fragment
     - every distinct 'Part Number' corresponds to a distinct flow
     - every part-number flow is measured in 'Number of items' and every exchange value is 1.0 item
     - every assembly is unique and none are re-used
    The 'Part Number' is the external reference used to retrieve the flow (which could be a part or an assembly). 
    The phrase '<Part Number> ASSEMBLY' is the external reference of the named fragment that produces the flow.
    returns: a top-level fragment.  Every sub-assembly is named after its part number; leaf fragments are unnamed 
    and may be duplicated.
    """
    refs = []
    xl = XlDict(sheet)
    for row in xl.iterrows():
        source = '%s|%d' % (sheet.name, row[0]+1)
        ref = _process_row(foreground, row, source)
        if ref is not None:
            refs.append(ref)

    return refs

# %%
xld = XlDict(xl)
i, row = next(xld.iterrows())

# %%
row.pop('Next Assembly')

# %%
f = _row_to_flow(fg, row)

# %%
f.external_ref
# Out:
# '74A400500-1017'

# %%
flow = fg['74A400594-1001']

# %%
flow.show()
# Out:
# Flow Entity (ref 74A400594-1001)
# origin: local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon
# reference: [local.qdb] Number of items [Item(s)]
#        Name: SUPPORT ASSY
#     Comment:
# Compartment: []
#       Level: 1.0
#   CasNumber:
#          PT: 1
#         QNA: 001

# %%
[str(k) for k in fg.fragments_with_flow(flow)]
# Out:
# ['(dfa83b2) -<- d2cd0 -<- -O    [   1 unit] SUPPORT ASSY ']

# %%
fg['74A400600-1017']

# %%
frags = fragment_from_xl_sheet(fg, xl)

# %%
frags[0].show_tree()
# Out:
#    -<--O   56c2a [       1 Item(s)] 74A400500-1017 ASSEMBLY
#     [   1 unit] 74A400500-1017 ASSEMBLY
#        | -<----: 00f54 (       1 Item(s)) WASHER, FLAT
#        | -<----: 0ee99 (       1 Item(s)) NUT,PLAIN,HEXAGON
#        | -<----: 104cf (       1 Item(s)) BOLT, SHOULDER
#        | -<----: 12f67 (       1 Item(s)) COTTER PIN
#        | -<----: 295bb (       1 Item(s)) BOLT-RETAINER
#        | -<----: 2cc7b (       1 Item(s)) NUT
#        | -<----: 2ee76 (       1 Item(s)) BOLT
#        | -<----: 3a6f6 (       1 Item(s)) PIN, COTTER
#        | -<----: 41e0e (       1 Item(s)) NUT, PLAIN, HEX
#        | -<----: 46f94 (       1 Item(s)) PLATE, IDENT
#        | -<----: 5f66f (       1 Item(s)) WASHER, TAB LOCK
#        | -<----: 67471 (       1 Item(s)) BOLT, SHOULDER
#        | -<----: 6e8b9 (       1 Item(s)) WASHER, FLAT
#        | -<----: 7c534 (       1 Item(s)) WASHER, FLAT
#        | -<----: 7de3c (       1 Item(s)) WASHER, KEY
#        | -<----: 808f8 (       1 Item(s)) PIN, PIVOT
#        | -<----: 825e7 (       1 Item(s)) WASHER,FLAT
#        | -<----: 98e49 (       1 Item(s)) PLATE, MOD
#        | -<----: abcc3 (       1 Item(s)) STUD
#        | -<----: acffc (       1 Item(s)) PLATE
#        | -<----: d12ae (       1 Item(s)) ADAPTER
#        | -<----: dfb3d (       1 Item(s)) WASHER, KEY
#        | -<----: ec805 (       1 Item(s)) WASHER, FLAT
#        | -<----: f2ce9 (       1 Item(s)) BOLT, SHOULDER
#        | -<----: f3041 (       1 Item(s)) NUT
#        | -<----: f3db6 (       1 Item(s)) SPACER, SLEEVE
#        | -<----: f4059 (       1 Item(s)) NUT, PLAIN
#        | -<----: f9de1 (       1 Item(s)) LOCKWIRE
#        | -<--O   62549 (       1 Item(s)) SUPPORT ASSY
#        |  [   1 unit] SUPPORT ASSY
#        |     | -<----: 87b6e (       1 Item(s)) RIVET
#        |     | -<----: 910c8 (       1 Item(s)) INSERT
#        |     | -<----: b07f1 (       1 Item(s)) TARGET
#        |     | -<----: bf88c (       1 Item(s)) SPACER
#        |     | -<----: fc250 (       1 Item(s)) SETSCREW
#        |     | -<----: febb2 (       1 Item(s)) INSERT
#        |     | -<--O   ff84d (       1 Item(s)) SUPPORT
#        |     |  [   1 unit] SUPPORT
#        |     |     | -<----: 0ad72 (       1 Item(s)) SUPPORT, CASTING
#        |     |     x
#        |     x
#        | -<--O   654f0 (       1 Item(s)) SUPPORT ASSY
#        |  [   1 unit] SUPPORT ASSY
#        |     | -<----: 3b468 (       1 Item(s)) INSERT
#        |     | -<--O   af94c (       1 Item(s)) SUPPORT
#        |     |  [   1 unit] SUPPORT
#        |     |     | -<----: 4be77 (       1 Item(s)) SUPPORT, CASTING
#        |     |     x
#        |     x
#        | -<--O   6d85d (       1 Item(s)) PLANING MECH ASSY
#        |  [   1 unit] PLANING MECH ASSY
#        |     | -<----: 18154 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 20cb0 (       1 Item(s)) BOLT
#        |     | -<----: 4655b (       1 Item(s)) NUT
#        |     | -<----: 509b9 (       1 Item(s)) PIN, COTTER
#        |     | -<----: 5e125 (       1 Item(s)) PIN, COTTER
#        |     | -<----: 611bb (       1 Item(s)) LOCKWIRE
#        |     | -<----: 6d6e7 (       1 Item(s)) BOLT
#        |     | -<----: a33be (       1 Item(s)) NUT
#        |     | -<----: e0ce3 (       1 Item(s)) WASHER, FLAT
#        |     | -<--O   44df7 (       1 Item(s)) BELLCRANK ASSY
#        |     |  [   1 unit] BELLCRANK ASSY
#        |     |     | -<----: 3e3cb (       1 Item(s)) BUSHING,PIVOT,PTFE
#        |     |     | -<----: 6acbc (       1 Item(s)) BUSHING
#        |     |     | -<----: bfe54 (       1 Item(s)) BUSHING, BELLCRANK
#        |     |     | -<--O   3c303 (       1 Item(s)) BELL CRANK
#        |     |     |  [   1 unit] BELL CRANK
#        |     |     |     | -<----: 8325d (       1 Item(s)) BELLCRANK, FORGING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   811a7 (       1 Item(s)) LINK ASSY, UPPER
#        |     |  [   1 unit] LINK ASSY, UPPER
#        |     |     | -<----: 02922 (       1 Item(s)) NUT (LH)
#        |     |     | -<----: 46ddb (       1 Item(s)) LOCKWIRE
#        |     |     | -<----: b9ef7 (       1 Item(s)) NUT (RH)
#        |     |     | -<----: e725b (       1 Item(s)) LOCKING DEVICE
#        |     |     | -<--O   18d35 (       1 Item(s)) ROD END ASSY (LH)
#        |     |     |  [   1 unit] ROD END ASSY (LH)
#        |     |     |     | -<----: f67ef (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   8fce9 (       1 Item(s)) ROD END ASSY (RH)
#        |     |     |  [   1 unit] ROD END ASSY (RH)
#        |     |     |     | -<----: 275c1 (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   a0c6c (       1 Item(s)) ROD, THREADED END
#        |     |     |  [   1 unit] ROD, THREADED END
#        |     |     |     | -<----: 0c005 (       1 Item(s)) ROD, SWAGING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   c4022 (       1 Item(s)) LINK ASSY, LOWER
#        |     |  [   1 unit] LINK ASSY, LOWER
#        |     |     | -<----: 08593 (       1 Item(s)) NUT,CASTLE
#        |     |     | -<----: 13c26 (       1 Item(s)) SPRING, LWR PLAN
#        |     |     | -<----: 22d05 (       1 Item(s)) PIN,COTTER
#        |     |     | -<----: 7b2ba (       1 Item(s)) LOCKING DEVICE
#        |     |     | -<----: ae161 (       1 Item(s)) SPOOL
#        |     |     | -<----: b5b1f (       1 Item(s)) SEAT
#        |     |     | -<----: b9449 (       1 Item(s)) NUT,PLAIN,HEX, JAM
#        |     |     | -<----: eb062 (       1 Item(s)) SCRAPER, LWR PLAN
#        |     |     | -<----: f5168 (       1 Item(s)) CYCLINDER, LOWER
#        |     |     | -<----: ff50c (       1 Item(s)) LOCKWIRE
#        |     |     | -<--O   6a93e (       1 Item(s)) ROD END ASSY
#        |     |     |  [   1 unit] ROD END ASSY
#        |     |     |     | -<----: 36c76 (       1 Item(s)) BEARING
#        |     |     |     | -<----: e8cfc (       1 Item(s)) ROD END
#        |     |     |     x
#        |     |     | -<--O   c707c (       1 Item(s)) CLEVIS ASSY
#        |     |     |  [   1 unit] CLEVIS ASSY
#        |     |     |     | -<----: 7bbe6 (       1 Item(s)) BUSHING
#        |     |     |     | -<----: c0259 (       1 Item(s)) CLEVIS
#        |     |     |     x
#        |     |     x
#        |     x
#        | -<--O   cb5a1 (       1 Item(s)) TRUNNION ASSY
#        |  [   1 unit] TRUNNION ASSY
#        |     | -<----: 0b0e9 (       1 Item(s)) BOLT,SHOULDER
#        |     | -<----: 109f6 (       1 Item(s)) WASHER
#        |     | -<----: 3d743 (       1 Item(s)) NUT
#        |     | -<----: 40e74 (       1 Item(s)) LOCK
#        |     | -<----: 41a72 (       1 Item(s)) COTTER PIN
#        |     | -<----: 4b541 (       1 Item(s)) PLUG, THREADED
#        |     | -<----: 5937a (       1 Item(s)) WASHER
#        |     | -<----: 5a046 (       1 Item(s)) WASHER
#        |     | -<----: 67c2c (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: 6b412 (       1 Item(s)) WASHER, KEY
#        |     | -<----: 82cde (       1 Item(s)) BRACKET
#        |     | -<----: 906c6 (       1 Item(s)) PIN, TRUNNION
#        |     | -<----: 9b57b (       1 Item(s)) COTTER PIN
#        |     | -<----: abd5b (       1 Item(s)) MACHINE SCREW
#        |     | -<----: b0cf4 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: b9b8a (       1 Item(s)) SPRING
#        |     | -<----: bb079 (       1 Item(s)) BRACKET
#        |     | -<----: c4676 (       1 Item(s)) BRACKET,SHACKLE
#        |     | -<----: ddf85 (       1 Item(s)) NUT
#        |     | -<----: e7009 (       1 Item(s)) BOLT, SHACKLE
#        |     | -<--O   0b593 (       1 Item(s)) TRUNNION ASSY
#        |     |  [   1 unit] TRUNNION ASSY
#        |     |     | -<----: 122b2 (       1 Item(s)) BUSHING
#        |     |     | -<----: 1f8f0 (       1 Item(s)) BUSHING
#        |     |     | -<----: 21a8b (       1 Item(s)) BUSHING
#        |     |     | -<----: 36123 (       1 Item(s)) BUSHING
#        |     |     | -<----: 59c98 (       1 Item(s)) BUSHING
#        |     |     | -<----: 871a0 (       1 Item(s)) FITTING, LUB.
#        |     |     | -<----: 92d84 (       1 Item(s)) BUSHING
#        |     |     | -<----: abf08 (       1 Item(s)) BUSHING
#        |     |     | -<----: dcd37 (       1 Item(s)) BUSHING
#        |     |     | -<----: f437a (       1 Item(s)) BUSHING
#        |     |     | -<--O   9c3e6 (       1 Item(s)) TRUNNION
#        |     |     |  [   1 unit] TRUNNION
#        |     |     |     | -<--O   94703 (       1 Item(s)) TRUNNION
#        |     |     |     |  [   1 unit] TRUNNION
#        |     |     |     |     | -<----: f7af0 (       1 Item(s)) TRUNNION, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   76fee (       1 Item(s)) RING, TIEDOWN
#        |     |  [   1 unit] RING, TIEDOWN
#        |     |     | -<----: 76ffc (       1 Item(s)) RING, TIEDOWN, FORGING
#        |     |     x
#        |     x
#        | -<--O   d926e (       1 Item(s)) SHOCK ABS ASSY
#        |  [   1 unit] SHOCK ABS ASSY
#        |     | -<----: 02ea3 (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: 07a12 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 09a6b (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: 0db2d (       1 Item(s)) NUT, GLAND
#        |     | -<----: 0e6f4 (       1 Item(s)) RING,SNUBBER
#        |     | -<----: 21726 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 253e2 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: 27726 (       1 Item(s)) PLATE, IDENT
#        |     | -<----: 297e7 (       1 Item(s)) NUT, ROUND
#        |     | -<----: 2c1a0 (       1 Item(s)) SCREW, LOCK
#        |     | -<----: 392ee (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 3bb02 (       1 Item(s)) PIN,METERING
#        |     | -<----: 3ee5f (       1 Item(s)) SCREW
#        |     | -<----: 4451c (       1 Item(s)) LOCK-PLATE,SERR
#        |     | -<----: 4bc6f (       1 Item(s)) HEAD, PISTON
#        |     | -<----: 4cf55 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 5f5ee (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: 64760 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: 66d05 (       1 Item(s)) VALVE, AIR, HIGH P
#        |     | -<----: 6ce9a (       1 Item(s)) SCRAPER, PISTON
#        |     | -<----: 771c8 (       1 Item(s)) GAGE, LOW PRES
#        |     | -<----: 7a1a7 (       1 Item(s)) LOCKWIRE
#        |     | -<----: 82e46 (       1 Item(s)) NUT,SELF-LOCKING
#        |     | -<----: 92af4 (       1 Item(s)) SCREW
#        |     | -<----: 95d02 (       1 Item(s)) BEARING, LOWER
#        |     | -<----: a205d (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: b4796 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: b76b4 (       1 Item(s)) PLATE,ORIFICE
#        |     | -<----: bd172 (       1 Item(s)) LOCK, NUT
#        |     | -<----: c08c5 (       1 Item(s)) WASHER
#        |     | -<----: ca980 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: d205a (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: d5c26 (       1 Item(s)) LOCK-PLATE, SERR
#        |     | -<----: dcad2 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: deda2 (       1 Item(s)) LOCK-PLATE, SERR
#        |     | -<----: e10c6 (       1 Item(s)) GAGE, HIGH PRES
#        |     | -<----: e509d (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: e5a0f (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: e70ad (       1 Item(s)) PISTON,SECONDARY
#        |     | -<----: e77b9 (       1 Item(s)) RETAINER, BACKUP
#        |     | -<----: e8ae0 (       1 Item(s)) PLATE,INSTRUCTION
#        |     | -<----: f490e (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: fab8a (       1 Item(s)) SCREW, SHOULDER
#        |     | -<----: fb44d (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: fc65e (       1 Item(s)) RETAINER, BACKUP
#        |     | -<--O   04973 (       1 Item(s)) PISTON ASSEMBLY
#        |     |  [   1 unit] PISTON ASSEMBLY
#        |     |     | -<----: 61849 (       1 Item(s)) BUSHING
#        |     |     | -<--O   efbe7 (       1 Item(s)) PISTON
#        |     |     |  [   1 unit] PISTON
#        |     |     |     | -<----: 6383b (       1 Item(s)) PISTON
#        |     |     |     x
#        |     |     x
#        |     | -<--O   78295 (       1 Item(s)) HEAD ASSEMBLY
#        |     |  [   1 unit] HEAD ASSEMBLY
#        |     |     | -<----: c27df (       1 Item(s)) FITTING, LUB.
#        |     |     | -<--O   14240 (       1 Item(s)) PLUG, EXPANSION
#        |     |     |  [   1 unit] PLUG, EXPANSION
#        |     |     |     | -<----: f2f86 (       1 Item(s)) PLUG
#        |     |     |     x
#        |     |     | -<--O   53c89 (       1 Item(s)) HEAD
#        |     |     |  [   1 unit] HEAD
#        |     |     |     | -<--O   e91b2 (       1 Item(s)) HEAD
#        |     |     |     |  [   1 unit] HEAD
#        |     |     |     |     | -<----: 5bcff (       1 Item(s)) HEAD, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     | -<--O   b728b (       1 Item(s)) BEARING
#        |     |     |  [   1 unit] BEARING
#        |     |     |     | -<----: 9ce83 (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   7ffae (       1 Item(s)) TUBE ASSEMBLY
#        |     |  [   1 unit] TUBE ASSEMBLY
#        |     |     | -<----: 7ac25 (       1 Item(s)) TUBE
#        |     |     | -<----: bfdf6 (       1 Item(s)) RETAINER
#        |     |     | -<----: db4ac (       1 Item(s)) PIN
#        |     |     | -<----: f8264 (       1 Item(s)) RING
#        |     |     x
#        |     | -<--O   b1c1b (       1 Item(s)) CYLINDER, OUTER
#        |     |  [   1 unit] CYLINDER, OUTER
#        |     |     | -<----: 46aa3 (       1 Item(s)) CYLINDER, OUTER
#        |     |     x
#        |     x
#        | -<--O   e7790 (       1 Item(s)) SCREW, CAP
#        |  [   1 unit] SCREW, CAP
#        |     | -<----: 91206 (       1 Item(s)) MAKE FROM VENDOR PART
#        |     x
#        | -<--O   e7f56 (       1 Item(s)) LEVER/AXLE ASSY
#        |  [   1 unit] LEVER/AXLE ASSY
#        |     | -<----: 0520b (       1 Item(s)) NUT, SELF LOCKING
#        |     | -<----: 0bf9b (       1 Item(s)) NUT, DRILLED JAM
#        |     | -<----: 1039b (       1 Item(s)) WASHER, CSK
#        |     | -<----: 18f08 (       1 Item(s)) BOLT, HEX HEAD
#        |     | -<----: 190bd (       1 Item(s)) PLUG, PROTECTIVE
#        |     | -<----: 1c1a9 (       1 Item(s)) NUT, DRILLED JAM
#        |     | -<----: 1c31d (       1 Item(s)) NUT, PLAIN, RND
#        |     | -<----: 234eb (       1 Item(s)) WASHER, LAMINATED
#        |     | -<----: 27ad3 (       1 Item(s)) BOLT, HEX HEAD
#        |     | -<----: 27c5c (       1 Item(s)) NUT, PLAIN
#        |     | -<----: 3f1cc (       1 Item(s)) NUT, PIN ASSY
#        |     | -<----: 468a6 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 4892d (       1 Item(s)) NUT, PLAIN
#        |     | -<----: 618fc (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 6350a (       1 Item(s)) PIN, COTTER
#        |     | -<----: 636a4 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 6af58 (       1 Item(s)) WASHER, KEY
#        |     | -<----: 6b584 (       1 Item(s)) ROLLER, UPLOCK
#        |     | -<----: 71f30 (       1 Item(s)) PIN, COTTER
#        |     | -<----: 73eb7 (       1 Item(s)) NUT
#        |     | -<----: 7d5b7 (       1 Item(s)) LOCKWIRE
#        |     | -<----: 7feed (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: 81737 (       1 Item(s)) SEAT, SPRING
#        |     | -<----: 8ae22 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: 90646 (       1 Item(s)) LINK, PLAIN
#        |     | -<----: 97db2 (       1 Item(s)) PACKING
#        |     | -<----: 9b020 (       1 Item(s)) BUSHING, CLAMP-UP
#        |     | -<----: a3dba (       1 Item(s)) PACKING
#        |     | -<----: acd62 (       1 Item(s)) WASHER, KEY, LWR
#        |     | -<----: afc14 (       1 Item(s)) PIN, COTTER
#        |     | -<----: baa2d (       1 Item(s)) BOLT, HEX HEAD
#        |     | -<----: bbde6 (       1 Item(s)) PACKING
#        |     | -<----: c6335 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: ca80a (       1 Item(s)) SPACER
#        |     | -<----: cfece (       1 Item(s)) LINK,OVERCENTER
#        |     | -<----: d4ce9 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: d9e33 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: da88f (       1 Item(s)) LOCK - AXLE CRANK
#        |     | -<----: dbce0 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: deef8 (       1 Item(s)) SPRING, OUTER
#        |     | -<----: dfba9 (       1 Item(s)) WASHER,FLAT
#        |     | -<----: e2a50 (       1 Item(s)) PIN,COTTER
#        |     | -<----: e7ff6 (       1 Item(s)) SPRING, INNER
#        |     | -<----: eb3dd (       1 Item(s)) TARGET,PROX SW
#        |     | -<----: f1925 (       1 Item(s)) NUT, AXLE
#        |     | -<--O   1dddf (       1 Item(s)) ROD ASSY, SPR
#        |     |  [   1 unit] ROD ASSY, SPR
#        |     |     | -<----: 8310b (       1 Item(s)) ROD
#        |     |     | -<----: ff13c (       1 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   2b1b9 (       1 Item(s)) BRKT ASSY, SPR
#        |     |  [   1 unit] BRKT ASSY, SPR
#        |     |     | -<----: 18ba1 (       1 Item(s)) BRACKET
#        |     |     | -<----: ac823 (       1 Item(s)) BUSHING
#        |     |     | -<----: b2bac (       1 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   36cef (       1 Item(s)) CRANK ASSY
#        |     |  [   1 unit] CRANK ASSY
#        |     |     | -<----: 16b34 (       1 Item(s)) FITTING, LUB.
#        |     |     | -<--O   27003 (       1 Item(s)) BEARING,PLAIN
#        |     |     |  [   1 unit] BEARING,PLAIN
#        |     |     |     | -<----: d7b1f (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   9e540 (       1 Item(s)) CRANK,AXLE
#        |     |     |  [   1 unit] CRANK,AXLE
#        |     |     |     | -<--O   a0134 (       1 Item(s)) CRANK,AXLE
#        |     |     |     |  [   1 unit] CRANK,AXLE
#        |     |     |     |     | -<----: c4319 (       1 Item(s)) CRANK, AXLE, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   40a36 (       1 Item(s)) BRKT ASSY, PROX
#        |     |  [   1 unit] BRKT ASSY, PROX
#        |     |     | -<----: 255a7 (       1 Item(s)) BUSHING
#        |     |     | -<--O   b5e9d (       1 Item(s)) BRACKET
#        |     |     |  [   1 unit] BRACKET
#        |     |     |     | -<----: 0746c (       1 Item(s)) BRACKET, CASTING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   53643 (       1 Item(s)) AXLE ASSY
#        |     |  [   1 unit] AXLE ASSY
#        |     |     | -<----: 6d3ee (       1 Item(s)) PACKING
#        |     |     | -<----: aec9e (       1 Item(s)) ADAPTER
#        |     |     | -<--O   3bad2 (       1 Item(s)) AXLE
#        |     |     |  [   1 unit] AXLE
#        |     |     |     | -<--O   53b61 (       1 Item(s)) AXLE
#        |     |     |     |  [   1 unit] AXLE
#        |     |     |     |     | -<----: 191cc (       1 Item(s)) AXLE, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   6e374 (       1 Item(s)) LEVER ASSY
#        |     |  [   1 unit] LEVER ASSY
#        |     |     | -<----: 023ae (       1 Item(s)) BUSHING
#        |     |     | -<----: 1dc91 (       1 Item(s)) BUSHING
#        |     |     | -<----: 2bce1 (       1 Item(s)) BUSHING
#        |     |     | -<----: 35a41 (       1 Item(s)) BUSHING
#        |     |     | -<----: 5f882 (       1 Item(s)) BUSHING
#        |     |     | -<----: 709e9 (       1 Item(s)) BUSHING
#        |     |     | -<----: 85a86 (       1 Item(s)) FITTING, LUB.
#        |     |     | -<----: f16d1 (       1 Item(s)) BUSHING
#        |     |     | -<----: fd8fb (       1 Item(s)) BUSHING
#        |     |     | -<--O   1f07f (       1 Item(s)) BEARING
#        |     |     |  [   1 unit] BEARING
#        |     |     |     | -<----: e874d (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   396a0 (       1 Item(s)) LEVER
#        |     |     |  [   1 unit] LEVER
#        |     |     |     | -<--O   c7018 (       1 Item(s)) LEVER
#        |     |     |     |  [   1 unit] LEVER
#        |     |     |     |     | -<----: 12de6 (       1 Item(s)) LEVER, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   70774 (       1 Item(s)) LINK ASSY, LWR
#        |     |  [   1 unit] LINK ASSY, LWR
#        |     |     | -<----: 84246 (       1 Item(s)) BUSHING
#        |     |     | -<----: d4a1b (       1 Item(s)) BUSHING
#        |     |     | -<--O   5f079 (       1 Item(s)) LINK
#        |     |     |  [   1 unit] LINK
#        |     |     |     | -<----: 5d799 (       1 Item(s)) LINK
#        |     |     |     x
#        |     |     x
#        |     | -<--O   7eb3d (       1 Item(s)) BOLT, ASSY, RETNR
#        |     |  [   1 unit] BOLT, ASSY, RETNR
#        |     |     | -<----: 0f73b (       1 Item(s)) BUSHING
#        |     |     | -<----: db1af (       1 Item(s)) BOLT-RETAINER
#        |     |     x
#        |     | -<--O   8f7a4 (       1 Item(s)) LINK ASSY, UPR
#        |     |  [   1 unit] LINK ASSY, UPR
#        |     |     | -<----: 26215 (       1 Item(s)) BUSHING
#        |     |     | -<----: 2f0db (       1 Item(s)) BUSHING
#        |     |     | -<----: 5074a (       1 Item(s)) LINK
#        |     |     | -<----: 590ec (       1 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   90cce (       1 Item(s)) YOKE ASSY
#        |     |  [   1 unit] YOKE ASSY
#        |     |     | -<----: 2952f (       1 Item(s)) YOKE
#        |     |     | -<----: 2c979 (       1 Item(s)) BUSHING
#        |     |     | -<----: 3b210 (       1 Item(s)) BUSHING
#        |     |     | -<----: 74e9f (       1 Item(s)) FITTING
#        |     |     x
#        |     | -<--O   ee426 (       1 Item(s)) PIN ASSY
#        |     |  [   1 unit] PIN ASSY
#        |     |     | -<----: 1cc3b (       1 Item(s)) BEARING
#        |     |     | -<--O   c68ba (       1 Item(s)) PIN
#        |     |     |  [   1 unit] PIN
#        |     |     |     | -<----: 39c40 (       1 Item(s)) PIN
#        |     |     |     x
#        |     |     x
#        |     x
#        x

# %%
len([k for k in frags[0].inventory()])
# Out:
# 223

# %%
str(frags[2])
# Out:
# '( ** ref) -<- 099d8 -<- ---:  [   1 Item(s)] 74A400605-2001 ASSEMBLY {74A400605-2001 ASSEMBLY}'

# %%
ff.show()
# Out:
# Flow Entity (ref 74A400594-1001)
# origin: local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon
# reference: [local.qdb] Number of items [Item(s)]
#        Name: SUPPORT ASSY
#     Comment:
#         QNA: 001
#       Level: 1.0
# Compartment: []
#          PT: 1
#   CasNumber:

# %%
ff.reference_entity.show()
# Out:
# QuantityRef catalog reference (flowproperties/01846770-4cfe-4a25-8ad9-919d8d378345)
# origin: local.qdb
# UUID: 01846770-4cfe-4a25-8ad9-919d8d378345
#    Name: Number of items
# Comment: Reference Flow Property Data Set of the International Reference Life Cycle Data System (ILCD).
