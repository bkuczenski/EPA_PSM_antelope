# %% [markdown]
# ## EPA Product System Hackathon
# OK, it's May 15- we have until May 30 to get something sweee-e-et finished.  What's it going to be?
#
# Here's the plan:
#  * make a forest of fragments from the spreadsheet product models
#  * generate list of interior nodes and cutoffs (via automatic traversal)
#  * manually process "laundry list" terminations
#    - get USEEIO working
#    - use USLCI
#    - use Ecoinvent
#    - use ELCD
#  * automatically terminate cutoff fragments to various processes, by scenario
#
# First task is to read the spreadsheets, and build the fragments

# %% [markdown]
# ## First Task: validate spreadsheets
# The only potentially invalid information in the spreadsheets is the parent-child relationship between parts and assemblies; MSrocka announced that the initial commit failed this validation. So here is a check.

# %%
import os
import xlrd

# %%
fg_dir = '/data/GitHub/2019/LCAproductsystemassembly_1/data-foreground/'
bg_dir = '/data/GitHub/2019/LCAproductsystemassembly_resources/data-background/'


class DuplicateAssembly(Exception):
    pass

# %%
from antelope_catalog.providers.xl_dict  import XlDict

# %%
def validate_sheet(sheet):
    """
    checks whether the sheet includes references to unrecognized assemblies; returns the names of the 
    unrecognized assemblies
    """
    xld = XlDict(sheet)
    seen = set()
    dups = set()
    for i, row in xld.iterrows():
        parent = row['Next Assembly']
        part = row['Part Number']
        if parent is not None:
            if parent not in seen:
                yield parent
            if parent in dups:
                raise DuplicateAssembly('%s (row %d)' % (parent, i))
                
        if part in seen:
            dups.add(part)
            print('!Duplicate part: %s (row %d)' % (part, i))
            
        else:
            seen.add(part)

# %%
def validate_workbook(book):
    all_m = set()
    for n in book.sheet_names():
        s = book.sheet_by_name(n)
        m = set(k for k in validate_sheet(s))
        print('%s: %s' % (n, m))
        all_m |= m
    return all_m

# %%
def validate_folder(folder):
    asm = set()
    mis = set()
    xlss = [k for k in os.listdir(folder)]
    for xls in xlss:
        try:
            xl = xlrd.open_workbook(os.path.join(folder, xls))
        except xlrd.XLRDError:
            continue
        print('Workbook: %s' % xls)
        print('Assemblies: %s' % xl.sheet_names())
        asm |= set(xl.sheet_names())
        
        m = validate_workbook(xl)
        print('Missing: %s\n' % m)
        mis |= m
    print('Cross-References: %s' % (asm & mis))
    print('Globally Missing: %s' % (mis - asm))

# %% [raw]
# # initial commit
# >>> validate_folder(fg_dir)
# Workbook: NLG F18EFG ABL.xlsx
# Assemblies: ['74A430500-1017', '74A430700-1009', '74A430800-1021']
# 74A430500-1017: set()
# 74A430700-1009: set()
# 74A430800-1021: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# 74A400500-1017: {'74A400600-1017', '74A400631-2003'}
# 74A400500-1018: {'74A400600-1017', '74A400631-2003'}
# 74A400700-1013: {'74A400700-2009', '74A400780-1001', '74A400700-1011'}
# 74A400700-1014: {'74A400700-1012', '74A400780-1001', '74A400700-2009'}
# 74A400800-1001: set()
# Missing: {'74A400780-1001', '74A400631-2003', '74A400700-1011', '74A400700-1012', '74A400600-1017', '74A400700-2009'}
#
# Cross-References: set()
# Globally Missing: {'74A400780-1001', '74A400700-1011', '74A400631-2003', '74A400700-2009', '74A400700-1012', '74A400600-1017'}

# %%
# updated-- we see the _c file has no validation errors
validate_folder(fg_dir)
# Out:
# Workbook: NLG F18EFG ABL.xlsx
# Assemblies: ['74A430500-1017', '74A430700-1009', '74A430800-1021']
# !Duplicate part: NAS516-1A (row 46)
# !Duplicate part: NAS516-1A (row 54)
# !Duplicate part: M83461/1-010 (row 67)
# !Duplicate part: AS5986-04 (row 69)
# !Duplicate part: NAS516-1A (row 70)
# !Duplicate part: MS20427M2C5 (row 134)
# !Duplicate part: M23053/6-105-0 (row 173)
# !Duplicate part: M23053/6-105-0 (row 176)
# !Duplicate part: NAS516-1A (row 248)
# !Duplicate part: MS24665-153 (row 251)
# !Duplicate part: MS24665-302 (row 252)
# !Duplicate part: NAS516-1A (row 268)
# !Duplicate part: 74A450914-2003 (row 281)
# !Duplicate part: 74A450982-2003 (row 282)
# !Duplicate part: 74A430912-2001 (row 294)
# !Duplicate part: 74A430979-2003 (row 309)
# !Duplicate part: 74A430979-2003 (row 312)
# !Duplicate part: 74A430954-2001 (row 319)
# !Duplicate part: M83461/1-010 (row 329)
# !Duplicate part: AS5986-04 (row 333)
# !Duplicate part: MS24665-153 (row 356)
# !Duplicate part: MS24665-302 (row 357)
# !Duplicate part: ST3M404C4 (row 362)
# !Duplicate part: ST3M404C6 (row 363)
# !Duplicate part: NAS1149E0432P (row 366)
# !Duplicate part: NAS1149E0463P (row 367)
# !Duplicate part: NAS1149E0632P (row 368)
# !Duplicate part: MS20995C32 (row 372)
# !Duplicate part: NAS516-1A (row 391)
# !Duplicate part: MS24665-151 (row 404)
# !Duplicate part: MS24665-302 (row 405)
# !Duplicate part: ST3M404C6 (row 409)
# !Duplicate part: NAS1149E0332P (row 410)
# !Duplicate part: NAS1149E0363P (row 411)
# !Duplicate part: NAS1149E0632P (row 412)
# !Duplicate part: NAS1149E0663P (row 413)
# !Duplicate part: MS20995C32 (row 424)
# 74A430500-1017: set()
# !Duplicate part: 74B430704-101 (row 18)
# !Duplicate part: 74B430705-103 (row 20)
# !Duplicate part: 74B430717-101 (row 27)
# 74A430700-1009: set()
# 74A430800-1021: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL_c.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1017: set()
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1018: set()
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1013: set()
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1014: set()
# 74A400800-1001: set()
# Missing: set()
#
# Workbook: MLG F18EFG ABL.xlsx
# Assemblies: ['74A400500-1017', '74A400500-1018', '74A400700-1013', '74A400700-1014', '74A400800-1001']
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1017: {'74A400600-1017', '74A400631-2003'}
# !Duplicate part: 74A400557-2001 (row 42)
# !Duplicate part: MS20995C32 (row 54)
# !Duplicate part: MS21209F1-15 (row 66)
# !Duplicate part: MS20995NC32 (row 134)
# !Duplicate part: ST4M197-6 (row 143)
# !Duplicate part: NAS516-1A (row 176)
# !Duplicate part: 74B400952-201 (row 202)
# !Duplicate part: NAS516-1A (row 215)
# !Duplicate part: MS24665-300 (row 224)
# !Duplicate part: MS24665-304 (row 226)
# !Duplicate part: ST3M404C6 (row 229)
# !Duplicate part: NAS1149C0463R (row 234)
# !Duplicate part: NAS1149C0663R (row 236)
# !Duplicate part: MS20995NC32 (row 245)
# !Duplicate part: NAS516-1A (row 261)
# !Duplicate part: MS24665-300 (row 285)
# !Duplicate part: MS24665-374 (row 286)
# !Duplicate part: ST3M404-12 (row 289)
# !Duplicate part: ST3M404C6 (row 290)
# !Duplicate part: NAS1149C0663R (row 293)
# !Duplicate part: NAS6706D19 (row 297)
# !Duplicate part: MS20995NC32 (row 298)
# 74A400500-1018: {'74A400600-1017', '74A400631-2003'}
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1013: {'74A400700-1011', '74A400700-2009', '74A400780-1001'}
# !Duplicate part: NAS516-1A (row 17)
# !Duplicate part: NAS516-1A (row 38)
# !Duplicate part: NAS516-1A (row 43)
# !Duplicate part: NAS516-1A (row 55)
# !Duplicate part: NAS516-1A (row 64)
# !Duplicate part: NAS516-1A (row 100)
# !Duplicate part: MS24665-153 (row 121)
# !Duplicate part: ST3M404C3 (row 124)
# 74A400700-1014: {'74A400700-2009', '74A400780-1001', '74A400700-1012'}
# 74A400800-1001: set()
# Missing: {'74A400700-1011', '74A400780-1001', '74A400700-1012', '74A400700-2009', '74A400600-1017', '74A400631-2003'}
#
# Cross-References: set()
# Globally Missing: {'74A400700-1011', '74A400700-1012', '74A400780-1001', '74A400700-2009', '74A400600-1017', '74A400631-2003'}

# %% [markdown]
# ## OK, on to the fragment building
# The Foreground interface allows us to create fragments, and the Qdb allows us to use canonical quantities by name.
#
# We observe that the spreadsheets include numerous duplicate parts, but no duplicate assemblies.  This means we don't need to worry about creating re-usable sub-fragments or checking them for consistency.

# %%
from antelope_catalog import LcCatalog

# %%
PROJECT_DIR = '/data/GitHub/2019/EPA_PSM_antelope/'
CAT = os.path.join(PROJECT_DIR, 'catalog')

# %%
cat = LcCatalog(CAT)
# Out:
# Loading JSON data from /data/GitHub/2019/EPA_PSM_antelope/catalog/reference-quantities.json:
# local.qdb: /data/GitHub/2019/EPA_PSM_antelope/catalog/reference-quantities.json
# local.qdb: /data/GitHub/lca-tools/lcatools/qdb/data/elcd_reference_quantities.json
# 6 new flow entities added (6 total)
# 25 new quantity entities added (25 total)

# %%
cat.show_interfaces()
# Out:
# local.qdb [basic, index, quantity]

# %%
# cat.get_resource('local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon').remove_archive()
fg = cat.create_foreground('psm-hackathon')
# Out:
# local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon: /data/GitHub/2019/EPA_PSM_antelope/catalog/psm-hackathon
# Loading /data/GitHub/2019/EPA_PSM_antelope/catalog/psm-hackathon
# 0 new fragment entities added (0 total)

# %%
xls = xlrd.open_workbook(os.path.join(fg_dir, 'MLG F18EFG ABL_c.xlsx'))
xl = xls.sheet_by_name(xls.sheet_names()[0])
# xld = XlDict(xl)

# %%
'''
Define fragment:
 o- a "configurable exchange" 
 o- core elements are a flow and a direction
 o- optional elements: 
    - parent node (default None => reference flow) (direction is given with respect to parent)
    - termination node (default None => cutoff flow)
    - exchange value (ratio between parent node activity level and terminal flow magnitude; default 1.0)
 o- configurable elements: 
    - termination node
    - exchange value 

What's happening below is simple and general:
 - each row designates a unique fragment and represents a (non-unique) flow
 - determine and retrieve flow based on part number
   = if flow does not exist, create
 - determine and retrieve parent based on next assembly
   = if parent does not exist or is None, fragment becomes reference fragment and gets a name
   = if name is already taken, that tells us there's duplication happening

Foreground interface needs to provide:
 - way to create flows and fragments
 - way to retrieve flows and fragments by reference
 - generate existing fragments with flow (opt. direction)

What about duplication?  Here are some thoughts:
 - multiple fragments that generate the same flow are fine and encouraged- that is how fragments become useful
 - "named" fragments should be synonymous with (or maybe a subset of?) "reference fragments" i.e. fragments with 
   no parent node
   * dev question: is it operable to 'name' fragments on creation, e.g. bypassing foreground.name_fragment()?
     (should [RFC 2119 "SHALL"] work; needs unit test)
 - In the present case, duplication of fragment subtrees is not a technical problem if it happens within a fragment
   subtree, but it does indicate a design problem and should probably be detected.  It seems like an error if 
   two different subfragments produce the same assembly- if the two fragments are different, the assemblies should be
   different, and if they are the same- they should be represented by the same reference fragment. 
   
   If a new record (a) already has a matching fragment and (b) that fragment has child fragments, then it 
   is a duplicate assembly. Two different approaches to that:
    = assume the existing fragment is correct and use it, [somehow] ignoring child records
    = check to see whether the existing fragment is the same as the duplicative records and raise an exception if 
      it isn't
   
   The current spreadsheet seems to not have duplication of subassemblies, but we will plan to catch them and 
   raise an exception.
 
'''

def _row_to_flow(foreground, row):
    """
    This function is specific to the EPA foregrounds and should be the final disposition of the row dict. 
    Part Number is popped to retrieve flow.  Part Name is popped to set flow name.
    """
    if 'Next Assembly' in row:
        raise AttributeError('"Next Assembly" should be popped')
    flow_ref = row.pop('Part Number')
    if flow_ref is None:
        raise ValueError('Part number cannot be none (row %d)' % i)
    flow_name = row.pop('Part Name')
    if flow_name is None:
        flow_name = '%s ASSEMBLY' % flow_ref
    flow = foreground[flow_ref]
    if flow is None:
        flow = foreground.new_flow(flow_name, 'Number of items', external_ref=flow_ref, **row)
        if foreground[flow_ref] is not flow:
            raise KeyError('Flow ref %s failed to properly register' % flow_ref)
    return flow


def _new_reference_fragment(foreground, flow, **kwargs):
    # create a new parent fragment
    parent_ref = '%s ASSEMBLY' % flow.external_ref
    if foreground[parent_ref] is not None:
        _ac = 0
        while True:
            parent_ref = '%s ASSEMBLY alt %d' % (flow.external_ref, _ac)
            if foreground[parent_ref] is not None:
                _ac += 1
                continue
            break
    frag = foreground.new_fragment(flow, 'Output', Name=parent_ref, **kwargs)
    foreground.name_fragment(frag, parent_ref)
    return frag


def _process_row(foreground, i_row, source):
    i, row = i_row
    parent_num = row.pop('Next Assembly')
    try:
        amount = float(row.pop('QNA'))
    except (TypeError, ValueError):
        amount = 1.0
    flow = _row_to_flow(foreground, row)
    # print('%s: %s' % (source, flow))
        
    exis = [k for k in foreground.fragments_with_flow(flow) if len([c for c in k.child_flows]) > 0]
    if len(exis) > 0:
        raise DuplicateAssembly('(row %d) flow: %s' % (i, flow.link))  # handle this if it comes up
        
    if parent_num is None:
        return _new_reference_fragment(foreground, flow, value=amount, Source=source)

    else:
        try:
            parent = next(k for k in foreground.fragments_with_flow(parent_num))
        except StopIteration:
            print('Bad parent reference: %s; creating new reference fragment' % parent_num)
            return _new_reference_fragment(foreground, flow, value=amount, Source=source)
                    
    frag = foreground.new_fragment(flow, 'Input', parent=parent, value=amount, Source=source)
    return


def fragment_from_xl_sheet(foreground, sheet):
    """
    This function makes the following assumptions:
     - every record corresponds to a distinct fragment
     - every distinct 'Part Number' corresponds to a distinct flow
     - every part-number flow is measured in 'Number of items' and every exchange value is 1.0 item
     - every assembly is unique and none are re-used
    The 'Part Number' is the external reference used to retrieve the flow (which could be a part or an assembly). 
    The phrase '<Part Number> ASSEMBLY' is the external reference of the named fragment that produces the flow.
    returns: a top-level fragment.  Every sub-assembly is named after its part number; leaf fragments are unnamed 
    and may be duplicated.
    """
    refs = []
    xl = XlDict(sheet)
    for row in xl.iterrows():
        source = '%s|%d' % (sheet.name, row[0]+1)
        ref = _process_row(foreground, row, source)
        if ref is not None:
            refs.append(ref)

    return refs

# %%
frags = fragment_from_xl_sheet(fg, xl)

# %%
frags[0].show_tree()
# Out:
#    -<--O   20e9d [       1 Item(s)] 74A400500-1017 ASSEMBLY
#     [   1 unit] 74A400500-1017 ASSEMBLY
#        | -<----: 00376 (       1 Item(s)) NUT
#        | -<----: 02210 (       1 Item(s)) WASHER, FLAT
#        | -<----: 0f435 (       1 Item(s)) NUT, PLAIN, HEX
#        | -<----: 2b4eb (       1 Item(s)) COTTER PIN
#        | -<----: 3c17f (       1 Item(s)) BOLT, SHOULDER
#        | -<----: 4260c (       1 Item(s)) PLATE
#        | -<----: 43850 (       1 Item(s)) BOLT-RETAINER
#        | -<----: 5a5e3 (       2 Item(s)) WASHER,FLAT
#        | -<----: 67716 (       2 Item(s)) WASHER, FLAT
#        | -<----: 6df47 (       1 Item(s)) BOLT, SHOULDER
#        | -<----: 7df48 (       1 Item(s)) PIN, PIVOT
#        | -<----: 80ac2 (       2 Item(s)) WASHER, FLAT
#        | -<----: 82b7e (       1 Item(s)) WASHER, KEY
#        | -<----: 8eb0f (       1 Item(s)) NUT,PLAIN,HEXAGON
#        | -<----: 98d06 (       1 Item(s)) BOLT
#        | -<----: 9e0f4 (       1 Item(s)) SPACER, SLEEVE
#        | -<----: a4dc7 (       1 Item(s)) PLATE, IDENT
#        | -<----: ab243 (       1 Item(s)) PIN, COTTER
#        | -<----: b8fcd (       1 Item(s)) ADAPTER
#        | -<----: b908c (       1 Item(s)) NUT
#        | -<----: c797e (       1 Item(s)) BOLT, SHOULDER
#        | -<----: c7f0d (       2 Item(s)) WASHER, KEY
#        | -<----: c97ea (       1 Item(s)) PLATE, MOD
#        | -<----: cd2b7 (       1 Item(s)) STUD
#        | -<----: d6cbd (       1 Item(s)) WASHER, TAB LOCK
#        | -<----: de6b3 (       2 Item(s)) NUT, PLAIN
#        | -<----: e223f (       2 Item(s)) WASHER, FLAT
#        | -<----: ecea8 (       1 Item(s)) LOCKWIRE
#        | -<--O   3df66 (       1 Item(s)) PLANING MECH ASSY
#        |  [   1 unit] PLANING MECH ASSY
#        |     | -<----: 0265a (       1 Item(s)) NUT
#        |     | -<----: 349c2 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 47842 (       1 Item(s)) PIN, COTTER
#        |     | -<----: 62820 (       1 Item(s)) NUT
#        |     | -<----: 69060 (       1 Item(s)) BOLT
#        |     | -<----: 8900d (       1 Item(s)) PIN, COTTER
#        |     | -<----: cd547 (       1 Item(s)) LOCKWIRE
#        |     | -<----: ce664 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: d4997 (       1 Item(s)) BOLT
#        |     | -<--O   38a0d (       1 Item(s)) LINK ASSY, LOWER
#        |     |  [   1 unit] LINK ASSY, LOWER
#        |     |     | -<----: 1d17e (       1 Item(s)) SCRAPER, LWR PLAN
#        |     |     | -<----: 30741 (       2 Item(s)) SEAT
#        |     |     | -<----: 677a2 (       1 Item(s)) SPOOL
#        |     |     | -<----: 70f14 (       1 Item(s)) PIN,COTTER
#        |     |     | -<----: 90833 (       1 Item(s)) LOCKWIRE
#        |     |     | -<----: ab417 (       1 Item(s)) LOCKING DEVICE
#        |     |     | -<----: d9321 (       1 Item(s)) SPRING, LWR PLAN
#        |     |     | -<----: d95c0 (       1 Item(s)) NUT,CASTLE
#        |     |     | -<----: df2e3 (       1 Item(s)) CYCLINDER, LOWER
#        |     |     | -<----: fd0f4 (       1 Item(s)) NUT,PLAIN,HEX, JAM
#        |     |     | -<--O   1b83e (       1 Item(s)) ROD END ASSY
#        |     |     |  [   1 unit] ROD END ASSY
#        |     |     |     | -<----: 4e59c (       1 Item(s)) ROD END
#        |     |     |     | -<----: bcdcf (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   9f2ad (       1 Item(s)) CLEVIS ASSY
#        |     |     |  [   1 unit] CLEVIS ASSY
#        |     |     |     | -<----: 047ed (       2 Item(s)) BUSHING
#        |     |     |     | -<----: 4daec (       1 Item(s)) CLEVIS
#        |     |     |     x
#        |     |     x
#        |     | -<--O   6ed33 (       1 Item(s)) LINK ASSY, UPPER
#        |     |  [   1 unit] LINK ASSY, UPPER
#        |     |     | -<----: 20840 (       1 Item(s)) NUT (RH)
#        |     |     | -<----: 3a73d (       1 Item(s)) LOCKWIRE
#        |     |     | -<----: 91119 (       1 Item(s)) NUT (LH)
#        |     |     | -<----: fa3de (       2 Item(s)) LOCKING DEVICE
#        |     |     | -<--O   5a263 (       1 Item(s)) ROD END ASSY (RH)
#        |     |     |  [   1 unit] ROD END ASSY (RH)
#        |     |     |     | -<----: 9f4bc (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   7f1ab (       1 Item(s)) ROD END ASSY (LH)
#        |     |     |  [   1 unit] ROD END ASSY (LH)
#        |     |     |     | -<----: 0806d (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   d0bf6 (       1 Item(s)) ROD, THREADED END
#        |     |     |  [   1 unit] ROD, THREADED END
#        |     |     |     | -<----: bdab8 (       1 Item(s)) ROD, SWAGING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   f28b6 (       1 Item(s)) BELLCRANK ASSY
#        |     |  [   1 unit] BELLCRANK ASSY
#        |     |     | -<----: 06158 (       2 Item(s)) BUSHING, BELLCRANK
#        |     |     | -<----: 90ea2 (       2 Item(s)) BUSHING,PIVOT,PTFE
#        |     |     | -<----: e9944 (       2 Item(s)) BUSHING
#        |     |     | -<--O   e005e (       1 Item(s)) BELL CRANK
#        |     |     |  [   1 unit] BELL CRANK
#        |     |     |     | -<----: bc792 (       1 Item(s)) BELLCRANK, FORGING
#        |     |     |     x
#        |     |     x
#        |     x
#        | -<--O   614f7 (       1 Item(s)) SUPPORT ASSY
#        |  [   1 unit] SUPPORT ASSY
#        |     | -<----: 22eca (       1 Item(s)) INSERT
#        |     | -<----: 2a4dc (       1 Item(s)) SPACER
#        |     | -<----: 31433 (       1 Item(s)) TARGET
#        |     | -<----: 54d61 (       3 Item(s)) INSERT
#        |     | -<----: 98141 (       1 Item(s)) SETSCREW
#        |     | -<----: f5916 (       2 Item(s)) RIVET
#        |     | -<--O   0efad (       1 Item(s)) SUPPORT
#        |     |  [   1 unit] SUPPORT
#        |     |     | -<----: 049ec (       1 Item(s)) SUPPORT, CASTING
#        |     |     x
#        |     x
#        | -<--O   89e18 (       1 Item(s)) LEVER/AXLE ASSY
#        |  [   1 unit] LEVER/AXLE ASSY
#        |     | -<----: 1c6be (       2 Item(s)) BOLT, SHOULDER
#        |     | -<----: 21be0 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 32567 (       2 Item(s)) NUT, PLAIN
#        |     | -<----: 3d3c4 (       1 Item(s)) PACKING
#        |     | -<----: 3fad7 (       1 Item(s)) LINK, PLAIN
#        |     | -<----: 43b01 (       1 Item(s)) PACKING
#        |     | -<----: 4c7fc (       1 Item(s)) PACKING
#        |     | -<----: 56540 (       1 Item(s)) PIN, COTTER
#        |     | -<----: 5a18d (       1 Item(s)) SPRING, OUTER
#        |     | -<----: 61e08 (       2 Item(s)) BOLT, HEX HEAD
#        |     | -<----: 657e7 (       1 Item(s)) LINK,OVERCENTER
#        |     | -<----: 6706a (       1 Item(s)) NUT, DRILLED JAM
#        |     | -<----: 6d003 (       1 Item(s)) NUT, PLAIN, RND
#        |     | -<----: 70327 (       1 Item(s)) PLUG, PROTECTIVE
#        |     | -<----: 756ff (       1 Item(s)) WASHER, CSK
#        |     | -<----: 76131 (       3 Item(s)) WASHER, KEY, LWR
#        |     | -<----: 7699a (       1 Item(s)) PIN, COTTER
#        |     | -<----: 7c776 (       1 Item(s)) SPRING, INNER
#        |     | -<----: 86d44 (       1 Item(s)) NUT, PLAIN
#        |     | -<----: 89060 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 8a875 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: 950f1 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: 9d587 (       1 Item(s)) SPACER
#        |     | -<----: 9d7e8 (       1 Item(s)) PIN,COTTER
#        |     | -<----: a1c48 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: a36db (       1 Item(s)) ROLLER, UPLOCK
#        |     | -<----: a86b4 (       1 Item(s)) TARGET,PROX SW
#        |     | -<----: a9363 (       2 Item(s)) WASHER,FLAT
#        |     | -<----: ab8aa (       2 Item(s)) WASHER, FLAT
#        |     | -<----: adfad (       1 Item(s)) WASHER, LAMINATED
#        |     | -<----: af9ce (       1 Item(s)) NUT, SELF LOCKING
#        |     | -<----: b44fd (       2 Item(s)) PIN, COTTER
#        |     | -<----: bf8a9 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: c6b66 (       1 Item(s)) LOCKWIRE
#        |     | -<----: cd6a5 (       1 Item(s)) BOLT, HEX HEAD
#        |     | -<----: d4dd4 (       1 Item(s)) NUT, PIN ASSY
#        |     | -<----: d774c (       1 Item(s)) WASHER, KEY
#        |     | -<----: e3d79 (       1 Item(s)) BOLT, HEX HEAD
#        |     | -<----: e7323 (       1 Item(s)) NUT
#        |     | -<----: edf81 (       2 Item(s)) BOLT, SHOULDER
#        |     | -<----: ee6f9 (       1 Item(s)) NUT, AXLE
#        |     | -<----: f0adf (       2 Item(s)) NUT, DRILLED JAM
#        |     | -<----: f40da (       1 Item(s)) BUSHING, CLAMP-UP
#        |     | -<----: f8104 (       1 Item(s)) LOCK - AXLE CRANK
#        |     | -<----: fef46 (       1 Item(s)) SEAT, SPRING
#        |     | -<--O   0d71c (       1 Item(s)) LEVER ASSY
#        |     |  [   1 unit] LEVER ASSY
#        |     |     | -<----: 17c2b (       2 Item(s)) BUSHING
#        |     |     | -<----: 20b49 (       1 Item(s)) BUSHING
#        |     |     | -<----: 25156 (       2 Item(s)) BUSHING
#        |     |     | -<----: 62520 (       2 Item(s)) BUSHING
#        |     |     | -<----: 693c3 (       5 Item(s)) FITTING, LUB.
#        |     |     | -<----: 693d8 (       1 Item(s)) BUSHING
#        |     |     | -<----: 9f456 (       2 Item(s)) BUSHING
#        |     |     | -<----: c19d6 (       1 Item(s)) BUSHING
#        |     |     | -<----: da069 (       1 Item(s)) BUSHING
#        |     |     | -<--O   cf72e (       1 Item(s)) BEARING
#        |     |     |  [   1 unit] BEARING
#        |     |     |     | -<----: dc6a6 (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   fce4e (       1 Item(s)) LEVER
#        |     |     |  [   1 unit] LEVER
#        |     |     |     | -<--O   bc57f (       1 Item(s)) LEVER
#        |     |     |     |  [   1 unit] LEVER
#        |     |     |     |     | -<----: 2d084 (       1 Item(s)) LEVER, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   2f7d8 (       1 Item(s)) LINK ASSY, UPR
#        |     |  [   1 unit] LINK ASSY, UPR
#        |     |     | -<----: 1a332 (       1 Item(s)) LINK
#        |     |     | -<----: 1cb9c (       2 Item(s)) BUSHING
#        |     |     | -<----: 7a57e (       2 Item(s)) BUSHING
#        |     |     | -<----: a381a (       2 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   3ad40 (       1 Item(s)) ROD ASSY, SPR
#        |     |  [   1 unit] ROD ASSY, SPR
#        |     |     | -<----: 16bd9 (       2 Item(s)) BUSHING
#        |     |     | -<----: 19505 (       1 Item(s)) ROD
#        |     |     x
#        |     | -<--O   4304a (       1 Item(s)) YOKE ASSY
#        |     |  [   1 unit] YOKE ASSY
#        |     |     | -<----: 5df48 (       2 Item(s)) BUSHING
#        |     |     | -<----: 7cf77 (       1 Item(s)) YOKE
#        |     |     | -<----: 9d46e (       2 Item(s)) BUSHING
#        |     |     | -<----: e8cb2 (       2 Item(s)) FITTING
#        |     |     x
#        |     | -<--O   50598 (       1 Item(s)) BRKT ASSY, SPR
#        |     |  [   1 unit] BRKT ASSY, SPR
#        |     |     | -<----: 5066f (       1 Item(s)) BRACKET
#        |     |     | -<----: b1196 (       1 Item(s)) BUSHING
#        |     |     | -<----: fc00c (       1 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   67bca (       1 Item(s)) PIN ASSY
#        |     |  [   1 unit] PIN ASSY
#        |     |     | -<----: 41c04 (       1 Item(s)) BEARING
#        |     |     | -<--O   c0358 (       1 Item(s)) PIN
#        |     |     |  [   1 unit] PIN
#        |     |     |     | -<----: 56347 (       1 Item(s)) PIN
#        |     |     |     x
#        |     |     x
#        |     | -<--O   934be (       1 Item(s)) BOLT, ASSY, RETNR
#        |     |  [   1 unit] BOLT, ASSY, RETNR
#        |     |     | -<----: 6ae4e (       1 Item(s)) BOLT-RETAINER
#        |     |     | -<----: bf91f (       1 Item(s)) BUSHING
#        |     |     x
#        |     | -<--O   df0c0 (       1 Item(s)) CRANK ASSY
#        |     |  [   1 unit] CRANK ASSY
#        |     |     | -<----: 055b8 (       1 Item(s)) FITTING, LUB.
#        |     |     | -<--O   092bf (       1 Item(s)) CRANK,AXLE
#        |     |     |  [   1 unit] CRANK,AXLE
#        |     |     |     | -<--O   e3c46 (       1 Item(s)) CRANK,AXLE
#        |     |     |     |  [   1 unit] CRANK,AXLE
#        |     |     |     |     | -<----: 07126 (       1 Item(s)) CRANK, AXLE, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     | -<--O   dbcbb (       1 Item(s)) BEARING,PLAIN
#        |     |     |  [   1 unit] BEARING,PLAIN
#        |     |     |     | -<----: 285ff (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   e655b (       1 Item(s)) BRKT ASSY, PROX
#        |     |  [   1 unit] BRKT ASSY, PROX
#        |     |     | -<----: 8bb25 (       1 Item(s)) BUSHING
#        |     |     | -<--O   2ea83 (       1 Item(s)) BRACKET
#        |     |     |  [   1 unit] BRACKET
#        |     |     |     | -<----: 26971 (       1 Item(s)) BRACKET, CASTING
#        |     |     |     x
#        |     |     x
#        |     | -<--O   e9d1a (       1 Item(s)) AXLE ASSY
#        |     |  [   1 unit] AXLE ASSY
#        |     |     | -<----: 8ff39 (       2 Item(s)) ADAPTER
#        |     |     | -<----: a1aa4 (       2 Item(s)) PACKING
#        |     |     | -<--O   d355a (       1 Item(s)) AXLE
#        |     |     |  [   1 unit] AXLE
#        |     |     |     | -<--O   cb941 (       1 Item(s)) AXLE
#        |     |     |     |  [   1 unit] AXLE
#        |     |     |     |     | -<----: 6dc52 (       1 Item(s)) AXLE, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   fbac0 (       1 Item(s)) LINK ASSY, LWR
#        |     |  [   1 unit] LINK ASSY, LWR
#        |     |     | -<----: a06b0 (       2 Item(s)) BUSHING
#        |     |     | -<----: bca66 (       2 Item(s)) BUSHING
#        |     |     | -<--O   bac38 (       1 Item(s)) LINK
#        |     |     |  [   1 unit] LINK
#        |     |     |     | -<----: 9344a (       1 Item(s)) LINK
#        |     |     |     x
#        |     |     x
#        |     x
#        | -<--O   928e3 (       1 Item(s)) SUPPORT ASSY
#        |  [   1 unit] SUPPORT ASSY
#        |     | -<----: ee2b4 (       4 Item(s)) INSERT
#        |     | -<--O   987f6 (       1 Item(s)) SUPPORT
#        |     |  [   1 unit] SUPPORT
#        |     |     | -<----: 04c0e (       1 Item(s)) SUPPORT, CASTING
#        |     |     x
#        |     x
#        | -<--O   9db26 (       1 Item(s)) SHOCK ABS ASSY
#        |  [   1 unit] SHOCK ABS ASSY
#        |     | -<----: 01ecd (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 04c3b (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: 1699f (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 1d216 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 1fbdc (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 2192b (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 22e1d (       1 Item(s)) PLATE, IDENT
#        |     | -<----: 2f104 (       1 Item(s)) PLATE,INSTRUCTION
#        |     | -<----: 30789 (       1 Item(s)) GAGE, LOW PRES
#        |     | -<----: 3be0a (       1 Item(s)) RING,SNUBBER
#        |     | -<----: 3c30e (       1 Item(s)) NUT,SELF-LOCKING
#        |     | -<----: 453de (       1 Item(s)) LOCK-PLATE, SERR
#        |     | -<----: 53ace (       1 Item(s)) LOCKWIRE
#        |     | -<----: 5cdaa (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 5fbac (       3 Item(s)) VALVE, AIR, HIGH P
#        |     | -<----: 62a31 (       1 Item(s)) SCRAPER, PISTON
#        |     | -<----: 6ae16 (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 6bfe3 (       2 Item(s)) LOCK-PLATE, SERR
#        |     | -<----: 6fb27 (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 78d48 (       1 Item(s)) NUT, GLAND
#        |     | -<----: 7cadc (       1 Item(s)) PIN,METERING
#        |     | -<----: 7d94a (       2 Item(s)) WASHER
#        |     | -<----: 7dc50 (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: 83de0 (       1 Item(s)) LOCK, NUT
#        |     | -<----: 8e181 (       1 Item(s)) NUT, ROUND
#        |     | -<----: 8ef7c (       1 Item(s)) SCREW
#        |     | -<----: 921b1 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: 983a5 (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: a23ba (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: a382e (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: a619a (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: aeb66 (       1 Item(s)) HEAD, PISTON
#        |     | -<----: b02cb (       1 Item(s)) BEARING, LOWER
#        |     | -<----: b08ec (       1 Item(s)) GAGE, HIGH PRES
#        |     | -<----: b6776 (       4 Item(s)) SCREW, SHOULDER
#        |     | -<----: bb485 (       1 Item(s)) SCREW
#        |     | -<----: c2e17 (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: cb4eb (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: cf954 (       1 Item(s)) PLATE,ORIFICE
#        |     | -<----: e03b0 (       1 Item(s)) PACKING,PREFORMED
#        |     | -<----: e14dc (       1 Item(s)) PACKING, PREFORMED
#        |     | -<----: e4b7e (       2 Item(s)) RETAINER, BACKUP
#        |     | -<----: f1b46 (       1 Item(s)) LOCK-PLATE,SERR
#        |     | -<----: f20a4 (       1 Item(s)) PISTON,SECONDARY
#        |     | -<----: f4814 (       1 Item(s)) SCREW, LOCK
#        |     | -<--O   a3e97 (       1 Item(s)) TUBE ASSEMBLY
#        |     |  [   1 unit] TUBE ASSEMBLY
#        |     |     | -<----: 19474 (       1 Item(s)) PIN
#        |     |     | -<----: 4677f (       1 Item(s)) RETAINER
#        |     |     | -<----: 6cbb8 (       1 Item(s)) TUBE
#        |     |     | -<----: aa817 (       1 Item(s)) RING
#        |     |     x
#        |     | -<--O   a843f (       1 Item(s)) CYLINDER, OUTER
#        |     |  [   1 unit] CYLINDER, OUTER
#        |     |     | -<----: 5ddc4 (       1 Item(s)) CYLINDER, OUTER
#        |     |     x
#        |     | -<--O   b15ab (       1 Item(s)) PISTON ASSEMBLY
#        |     |  [   1 unit] PISTON ASSEMBLY
#        |     |     | -<----: 4dab6 (       2 Item(s)) BUSHING
#        |     |     | -<--O   6335d (       1 Item(s)) PISTON
#        |     |     |  [   1 unit] PISTON
#        |     |     |     | -<----: 677d3 (       1 Item(s)) PISTON
#        |     |     |     x
#        |     |     x
#        |     | -<--O   e9082 (       1 Item(s)) HEAD ASSEMBLY
#        |     |  [   1 unit] HEAD ASSEMBLY
#        |     |     | -<----: e14a3 (       1 Item(s)) FITTING, LUB.
#        |     |     | -<--O   4bd5c (       1 Item(s)) BEARING
#        |     |     |  [   1 unit] BEARING
#        |     |     |     | -<----: c771a (       1 Item(s)) BEARING
#        |     |     |     x
#        |     |     | -<--O   537d1 (       1 Item(s)) PLUG, EXPANSION
#        |     |     |  [   1 unit] PLUG, EXPANSION
#        |     |     |     | -<----: 6b7da (       1 Item(s)) PLUG
#        |     |     |     x
#        |     |     | -<--O   d9553 (       1 Item(s)) HEAD
#        |     |     |  [   1 unit] HEAD
#        |     |     |     | -<--O   fcd79 (       1 Item(s)) HEAD
#        |     |     |     |  [   1 unit] HEAD
#        |     |     |     |     | -<----: e785e (       1 Item(s)) HEAD, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     x
#        | -<--O   c13b4 (       1 Item(s)) TRUNNION ASSY
#        |  [   1 unit] TRUNNION ASSY
#        |     | -<----: 18377 (       1 Item(s)) WASHER, KEY
#        |     | -<----: 1efaf (       1 Item(s)) COTTER PIN
#        |     | -<----: 23e69 (       2 Item(s)) BRACKET,SHACKLE
#        |     | -<----: 2bb3f (       2 Item(s)) WASHER
#        |     | -<----: 353c9 (       2 Item(s)) BOLT, SHACKLE
#        |     | -<----: 42550 (       3 Item(s)) COTTER PIN
#        |     | -<----: 45b9d (       3 Item(s)) NUT
#        |     | -<----: 48f0f (       1 Item(s)) BOLT,SHOULDER
#        |     | -<----: 51d24 (       3 Item(s)) WASHER
#        |     | -<----: 63817 (       1 Item(s)) BOLT, SHOULDER
#        |     | -<----: 770be (       1 Item(s)) PLUG, THREADED
#        |     | -<----: 999ba (       1 Item(s)) PIN, TRUNNION
#        |     | -<----: a8e8f (       1 Item(s)) BRACKET
#        |     | -<----: ca8ce (       2 Item(s)) SPRING
#        |     | -<----: cad74 (       1 Item(s)) WASHER, FLAT
#        |     | -<----: d0fb6 (       1 Item(s)) BRACKET
#        |     | -<----: e7114 (       1 Item(s)) LOCK
#        |     | -<----: eb374 (       1 Item(s)) NUT
#        |     | -<----: f4c00 (       1 Item(s)) MACHINE SCREW
#        |     | -<----: fda68 (       1 Item(s)) WASHER
#        |     | -<--O   c50dc (       1 Item(s)) TRUNNION ASSY
#        |     |  [   1 unit] TRUNNION ASSY
#        |     |     | -<----: 1cc3d (       3 Item(s)) FITTING, LUB.
#        |     |     | -<----: 1ce87 (       2 Item(s)) BUSHING
#        |     |     | -<----: 4c969 (       4 Item(s)) BUSHING
#        |     |     | -<----: 50330 (       1 Item(s)) BUSHING
#        |     |     | -<----: a0f88 (       1 Item(s)) BUSHING
#        |     |     | -<----: bfa7e (       2 Item(s)) BUSHING
#        |     |     | -<----: c3728 (       1 Item(s)) BUSHING
#        |     |     | -<----: d0838 (       1 Item(s)) BUSHING
#        |     |     | -<----: fd841 (       1 Item(s)) BUSHING
#        |     |     | -<----: fece6 (       2 Item(s)) BUSHING
#        |     |     | -<--O   dec12 (       1 Item(s)) TRUNNION
#        |     |     |  [   1 unit] TRUNNION
#        |     |     |     | -<--O   a5dd9 (       1 Item(s)) TRUNNION
#        |     |     |     |  [   1 unit] TRUNNION
#        |     |     |     |     | -<----: 40db9 (       1 Item(s)) TRUNNION, FORGING
#        |     |     |     |     x
#        |     |     |     x
#        |     |     x
#        |     | -<--O   df1dd (       2 Item(s)) RING, TIEDOWN
#        |     |  [   1 unit] RING, TIEDOWN
#        |     |     | -<----: abb99 (       1 Item(s)) RING, TIEDOWN, FORGING
#        |     |     x
#        |     x
#        | -<--O   d97a2 (       2 Item(s)) SCREW, CAP
#        |  [   1 unit] SCREW, CAP
#        |     | -<----: fbc9a (       1 Item(s)) MAKE FROM VENDOR PART
#        |     x
#        x

# %% [markdown]
# The fragment is designed to function as a self-aggregating unit process.  The 'inventory' command will report its aggregated inputs and outputs for a unit flow of the reference fragment.

# %%
([str(k) for k in frags[0].inventory()])
# Out:
# [' Input:     [10 [Item(s)]]     FITTING, LUB. []',
#  ' Input:     [7 [Item(s)]]     INSERT []',
#  ' Input:     [4 [Item(s)]]     COTTER PIN []',
#  ' Input:     [4 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [4 [Item(s)]]     LOCKWIRE []',
#  ' Input:     [4 [Item(s)]]     BUSHING []',
#  ' Input:     [4 [Item(s)]]     BUSHING []',
#  ' Input:     [4 [Item(s)]]     SCREW, SHOULDER []',
#  ' Input:     [4 [Item(s)]]     BUSHING []',
#  ' Input:     [3 [Item(s)]]     NUT []',
#  ' Input:     [3 [Item(s)]]     PIN, COTTER []',
#  ' Input:     [3 [Item(s)]]     WASHER, KEY, LWR []',
#  ' Input:     [3 [Item(s)]]     VALVE, AIR, HIGH P []',
#  ' Input:     [3 [Item(s)]]     NUT []',
#  ' Input:     [3 [Item(s)]]     WASHER []',
#  ' Input:     [2 [Item(s)]]     BEARING []',
#  ' Input:     [2 [Item(s)]]     SEAT []',
#  ' Input:     [2 [Item(s)]]     PIN,COTTER []',
#  ' Input:     [2 [Item(s)]]     BOLT []',
#  ' Input:     [2 [Item(s)]]     LOCKWIRE []',
#  ' Input:     [2 [Item(s)]]     LOCKING DEVICE []',
#  ' Input:     [2 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [2 [Item(s)]]     BUSHING, BELLCRANK []',
#  ' Input:     [2 [Item(s)]]     BUSHING,PIVOT,PTFE []',
#  ' Input:     [2 [Item(s)]]     WASHER,FLAT []',
#  ' Input:     [2 [Item(s)]]     RIVET []',
#  ' Input:     [2 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     NUT, PLAIN []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     FITTING []',
#  ' Input:     [2 [Item(s)]]     BOLT, HEX HEAD []',
#  ' Input:     [2 [Item(s)]]     WASHER,FLAT []',
#  ' Input:     [2 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [2 [Item(s)]]     PIN, COTTER []',
#  ' Input:     [2 [Item(s)]]     ADAPTER []',
#  ' Input:     [2 [Item(s)]]     PACKING []',
#  ' Input:     [2 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [2 [Item(s)]]     NUT, DRILLED JAM []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     LOCK-PLATE, SERR []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     WASHER []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     RETAINER, BACKUP []',
#  ' Input:     [2 [Item(s)]]     NUT []',
#  ' Input:     [2 [Item(s)]]     BRACKET,SHACKLE []',
#  ' Input:     [2 [Item(s)]]     WASHER []',
#  ' Input:     [2 [Item(s)]]     BOLT, SHACKLE []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     BUSHING []',
#  ' Input:     [2 [Item(s)]]     SPRING []',
#  ' Input:     [2 [Item(s)]]     RING, TIEDOWN, FORGING []',
#  ' Input:     [2 [Item(s)]]     WASHER, KEY []',
#  ' Input:     [2 [Item(s)]]     MAKE FROM VENDOR PART []',
#  ' Input:     [2 [Item(s)]]     NUT, PLAIN []',
#  ' Input:     [2 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [1 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [1 [Item(s)]]     NUT, PLAIN, HEX []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     NUT []',
#  ' Input:     [1 [Item(s)]]     ROD END []',
#  ' Input:     [1 [Item(s)]]     SCRAPER, LWR PLAN []',
#  ' Input:     [1 [Item(s)]]     SPOOL []',
#  ' Input:     [1 [Item(s)]]     CLEVIS []',
#  ' Input:     [1 [Item(s)]]     LOCKING DEVICE []',
#  ' Input:     [1 [Item(s)]]     SPRING, LWR PLAN []',
#  ' Input:     [1 [Item(s)]]     NUT,CASTLE []',
#  ' Input:     [1 [Item(s)]]     CYCLINDER, LOWER []',
#  ' Input:     [1 [Item(s)]]     NUT,PLAIN,HEX, JAM []',
#  ' Input:     [1 [Item(s)]]     PIN, COTTER []',
#  ' Input:     [1 [Item(s)]]     NUT (RH) []',
#  ' Input:     [1 [Item(s)]]     BEARING []',
#  ' Input:     [1 [Item(s)]]     BEARING []',
#  ' Input:     [1 [Item(s)]]     NUT (LH) []',
#  ' Input:     [1 [Item(s)]]     ROD, SWAGING []',
#  ' Input:     [1 [Item(s)]]     BOLT []',
#  ' Input:     [1 [Item(s)]]     BELLCRANK, FORGING []',
#  ' Input:     [1 [Item(s)]]     PLATE []',
#  ' Input:     [1 [Item(s)]]     BOLT-RETAINER []',
#  ' Input:     [1 [Item(s)]]     SUPPORT, CASTING []',
#  ' Input:     [1 [Item(s)]]     INSERT []',
#  ' Input:     [1 [Item(s)]]     SPACER []',
#  ' Input:     [1 [Item(s)]]     TARGET []',
#  ' Input:     [1 [Item(s)]]     SETSCREW []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     PIN, PIVOT []',
#  ' Input:     [1 [Item(s)]]     WASHER, KEY []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BEARING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     LEVER, FORGING []',
#  ' Input:     [1 [Item(s)]]     LINK []',
#  ' Input:     [1 [Item(s)]]     ROD []',
#  ' Input:     [1 [Item(s)]]     PACKING []',
#  ' Input:     [1 [Item(s)]]     LINK, PLAIN []',
#  ' Input:     [1 [Item(s)]]     YOKE []',
#  ' Input:     [1 [Item(s)]]     PACKING []',
#  ' Input:     [1 [Item(s)]]     PACKING []',
#  ' Input:     [1 [Item(s)]]     BRACKET []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     PIN, COTTER []',
#  ' Input:     [1 [Item(s)]]     SPRING, OUTER []',
#  ' Input:     [1 [Item(s)]]     LINK,OVERCENTER []',
#  ' Input:     [1 [Item(s)]]     NUT, DRILLED JAM []',
#  ' Input:     [1 [Item(s)]]     PIN []',
#  ' Input:     [1 [Item(s)]]     NUT, PLAIN, RND []',
#  ' Input:     [1 [Item(s)]]     PLUG, PROTECTIVE []',
#  ' Input:     [1 [Item(s)]]     WASHER, CSK []',
#  ' Input:     [1 [Item(s)]]     SPRING, INNER []',
#  ' Input:     [1 [Item(s)]]     NUT, PLAIN []',
#  ' Input:     [1 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [1 [Item(s)]]     BOLT-RETAINER []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     SPACER []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     ROLLER, UPLOCK []',
#  ' Input:     [1 [Item(s)]]     TARGET,PROX SW []',
#  ' Input:     [1 [Item(s)]]     WASHER, LAMINATED []',
#  ' Input:     [1 [Item(s)]]     NUT, SELF LOCKING []',
#  ' Input:     [1 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [1 [Item(s)]]     BOLT, HEX HEAD []',
#  ' Input:     [1 [Item(s)]]     NUT, PIN ASSY []',
#  ' Input:     [1 [Item(s)]]     WASHER, KEY []',
#  ' Input:     [1 [Item(s)]]     CRANK, AXLE, FORGING []',
#  ' Input:     [1 [Item(s)]]     BEARING []',
#  ' Input:     [1 [Item(s)]]     BOLT, HEX HEAD []',
#  ' Input:     [1 [Item(s)]]     BRACKET, CASTING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     AXLE, FORGING []',
#  ' Input:     [1 [Item(s)]]     NUT, AXLE []',
#  ' Input:     [1 [Item(s)]]     BUSHING, CLAMP-UP []',
#  ' Input:     [1 [Item(s)]]     LOCK - AXLE CRANK []',
#  ' Input:     [1 [Item(s)]]     LINK []',
#  ' Input:     [1 [Item(s)]]     SEAT, SPRING []',
#  ' Input:     [1 [Item(s)]]     NUT,PLAIN,HEXAGON []',
#  ' Input:     [1 [Item(s)]]     SUPPORT, CASTING []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PACKING,PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PLATE, IDENT []',
#  ' Input:     [1 [Item(s)]]     PLATE,INSTRUCTION []',
#  ' Input:     [1 [Item(s)]]     GAGE, LOW PRES []',
#  ' Input:     [1 [Item(s)]]     RING,SNUBBER []',
#  ' Input:     [1 [Item(s)]]     NUT,SELF-LOCKING []',
#  ' Input:     [1 [Item(s)]]     LOCK-PLATE, SERR []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     SCRAPER, PISTON []',
#  ' Input:     [1 [Item(s)]]     NUT, GLAND []',
#  ' Input:     [1 [Item(s)]]     PIN,METERING []',
#  ' Input:     [1 [Item(s)]]     LOCK, NUT []',
#  ' Input:     [1 [Item(s)]]     NUT, ROUND []',
#  ' Input:     [1 [Item(s)]]     SCREW []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PIN []',
#  ' Input:     [1 [Item(s)]]     RETAINER []',
#  ' Input:     [1 [Item(s)]]     TUBE []',
#  ' Input:     [1 [Item(s)]]     RING []',
#  ' Input:     [1 [Item(s)]]     PACKING,PREFORMED []',
#  ' Input:     [1 [Item(s)]]     CYLINDER, OUTER []',
#  ' Input:     [1 [Item(s)]]     HEAD, PISTON []',
#  ' Input:     [1 [Item(s)]]     BEARING, LOWER []',
#  ' Input:     [1 [Item(s)]]     GAGE, HIGH PRES []',
#  ' Input:     [1 [Item(s)]]     PISTON []',
#  ' Input:     [1 [Item(s)]]     SCREW []',
#  ' Input:     [1 [Item(s)]]     PLATE,ORIFICE []',
#  ' Input:     [1 [Item(s)]]     PACKING,PREFORMED []',
#  ' Input:     [1 [Item(s)]]     PACKING, PREFORMED []',
#  ' Input:     [1 [Item(s)]]     BEARING []',
#  ' Input:     [1 [Item(s)]]     PLUG []',
#  ' Input:     [1 [Item(s)]]     HEAD, FORGING []',
#  ' Input:     [1 [Item(s)]]     LOCK-PLATE,SERR []',
#  ' Input:     [1 [Item(s)]]     PISTON,SECONDARY []',
#  ' Input:     [1 [Item(s)]]     SCREW, LOCK []',
#  ' Input:     [1 [Item(s)]]     SPACER, SLEEVE []',
#  ' Input:     [1 [Item(s)]]     PLATE, IDENT []',
#  ' Input:     [1 [Item(s)]]     ADAPTER []',
#  ' Input:     [1 [Item(s)]]     WASHER, KEY []',
#  ' Input:     [1 [Item(s)]]     COTTER PIN []',
#  ' Input:     [1 [Item(s)]]     BOLT,SHOULDER []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     PLUG, THREADED []',
#  ' Input:     [1 [Item(s)]]     PIN, TRUNNION []',
#  ' Input:     [1 [Item(s)]]     BRACKET []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     TRUNNION, FORGING []',
#  ' Input:     [1 [Item(s)]]     BUSHING []',
#  ' Input:     [1 [Item(s)]]     WASHER, FLAT []',
#  ' Input:     [1 [Item(s)]]     BRACKET []',
#  ' Input:     [1 [Item(s)]]     LOCK []',
#  ' Input:     [1 [Item(s)]]     MACHINE SCREW []',
#  ' Input:     [1 [Item(s)]]     WASHER []',
#  ' Input:     [1 [Item(s)]]     BOLT, SHOULDER []',
#  ' Input:     [1 [Item(s)]]     PLATE, MOD []',
#  ' Input:     [1 [Item(s)]]     STUD []',
#  ' Input:     [1 [Item(s)]]     WASHER, TAB LOCK []',
#  'Output: {*} [1 [Item(s)]] {*} 74A400500-1017 ASSEMBLY []']

# %%
f1 = fragment_from_xl_sheet(fg, xls.sheet_by_name(xls.sheet_names()[1]))
[k for k in f1.inventory()]
# Out:
# ---------------------------------------------------------------------------
# DuplicateAssembly                         Traceback (most recent call last)
# <ipython-input-18-b045f6ba96f3> in <module>
# ----> 1 f1 = fragment_from_xl_sheet(fg, xls.sheet_by_name(xls.sheet_names()[1]))
#       2 [k for k in f1.inventory()]
#
# <ipython-input-14-6863bf522d85> in fragment_from_xl_sheet(foreground, sheet)
#     127     for row in xl.iterrows():
#     128         source = '%s|%d' % (sheet.name, row[0]+1)
# --> 129         ref = _process_row(foreground, row, source)
#     130         if ref is not None:
#     131             refs.append(ref)
#
# <ipython-input-14-6863bf522d85> in _process_row(foreground, i_row, source)
#      95     exis = [k for k in foreground.fragments_with_flow(flow) if len([c for c in k.child_flows]) > 0]
#      96     if len(exis) > 0:
# ---> 97         raise DuplicateAssembly('(row %d) flow: %s' % (i, flow.link))  # handle this if it comes up
#      98
#      99     if parent_num is None:
#
# DuplicateAssembly: (row 12) flow: local.data.GitHub.2019.EPA_PSM_antelope.catalog.psm-hackathon/74A400561-1005

# %% [markdown]
# ### Duplicate Assemblies
# OK, so now we see an interesting situation: the same subassembly, in this case `74A400561-1005`, is used in two different top-level assemblies.  We created the `DuplicateAssembly` exception to catch this, and now it has.
#
# Just to be sure: how does `msrocka`'s code deal with this? ans: it doesn't; the `74A00561-1005` assembly in his toy repo has all its exchanges duplicated. (presumably he has corrected this later)
#
# How do _we_ want to deal with it? Well, here are two ways:
#  1. do nothing; ignore the exception. This will lead to the assembly being replicated as a subfragment tree every time it appears, but will still be correct.
#  2. Fork out the assembly into a new reference fragment and reuse it. Doing this faces the possibility that the two subassembly instances are not identical.
#
# To deal with this second problem robustly, we want to screen the incoming "second" instance and verify that it is indeed identical to the "first".  Two ways occur to me to do that: (a) assume it's correct and check for discrepancies, line-by-line; (b) build two separate fragments and then check later to see if they are identical.
#
# This is, unfortunately, a graph isomorphism problem.  It is surely something I would want the interface to take care of, though.
#
# My approach to this will be to:
#  - only look for duplicates within the sheet
#  - build fragments including duplicated subassemblies
#  - after the fact, hunt for fragments that produce the same flow
#  - (*shudder*) determine if they are isomorphic
#  - if so, branch them into separate reference fragments and reuse them
#
# I'll do this in the class and not in a notebook.
